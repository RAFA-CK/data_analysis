# %% [markdown]
# <a href="https://colab.research.google.com/github/RAFA-CK/data_analysis/blob/main/Untitled12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = {
    "customer":["A","B","C"],
    "Balance" : [5000,1200,1600]

}
df=pd.DataFrame(data)
print(df)
df.describe()
# Out:
#   customer  Balance
# 0        A     5000
# 1        B     1200
# 2        C     1600
#            Balance
# count     3.000000
# mean   2600.000000
# std    2088.061302
# min    1200.000000
# 25%    1400.000000
# 50%    1600.000000
# 75%    3300.000000
# max    5000.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Balance'].plot(kind='hist', bins=20, title='Balance')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_1['Balance'].plot(kind='line', figsize=(8, 4), title='Balance')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
# ...

# %% [markdown]
# **prediction**

# %%
df["failure_rate"] = df["Balance"]<1500
df
# Out:
#   customer  Balance  failure_rate
# 0        A     5000         False
# 1        B     1200          True
# 2        C     1600         False

# %%
}

# %%
import matplotlib.pyplot as plt
plt.bar(df["customer"],df["Balance"])
plt.xlabel("customer")
plt.ylabel("Balance")
plt.title("customer Balance")
plt.show()

# %%
df.plot(
    x="customer",
    y="Balance",
    kind="scatter",
    title="customer balance"
)
plt.show()

# %%
import numpy as np
conditions=[
    df["Balance"]<1500
]
df()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1890881498.py in <cell line: 0>()
#       3     df["Balance"]<1500
#       4 ]
# ----> 5 df()
#
# TypeError: 'DataFrame' object is not callable

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-855723b0-7e5a-4376-a1b0-79970f4ccb09" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-855723b0-7e5a-4376-a1b0-79970f4ccb09">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv("annual-enterprise-survey-2024-financial-year-provisional.csv")
